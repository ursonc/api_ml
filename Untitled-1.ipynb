# %%
import streamlit as st
import requests
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderServiceError
import datetime
import logging

# ---------------------------
# Setup Logging
# ---------------------------
logging.basicConfig(level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

# ---------------------------
# Initialize Geolocator with a Unique User Agent
# ---------------------------
geolocator = Nominatim(user_agent="property_price_prediction_app")

# ---------------------------
# Streamlit UI Configuration
# ---------------------------
st.title("🏠 Property Price Prediction")

st.markdown("""
This application predicts the price of a property based on various features. Please provide the necessary details below.
""")

# ---------------------------
# Input Form for Property Details
# ---------------------------

# Total Area
total_area_sqm = st.number_input(
    "🛋️ Enter the total area in square meters:",
    min_value=0.0,
    format="%.2f",
    help="Total living area of the property."
)

# Construction Year with Dynamic Maximum Value
current_year = datetime.datetime.now().year
construction_year = st.number_input(
    "🏗️ Enter the construction year:",
    min_value=1900,
    max_value=current_year,
    value=2000,
    step=1,
    help="Year the property was constructed."
)

# Number of Bedrooms
nbr_bedrooms = st.number_input(
    "🛏️ Enter the number of bedrooms:",
    min_value=1,
    step=1,
    help="Total number of bedrooms in the property."
)

# Terrace Information
fl_terrace = st.checkbox("🌿 Does the property have a terrace?")
if fl_terrace:
    terrace_sqm = st.number_input(
        "📐 Enter the terrace area in square meters:",
        min_value=0.0,
        format="%.2f",
        help="Total area of the terrace."
    )
else:
    terrace_sqm = 0.0  # Default value when terrace is not present

# Flood Zone Information
fl_floodzone = st.checkbox("🌊 Is the property in a flood zone?")

# Address Input for Geocoding
address = st.text_input(
    "📍 Enter the property address or location:",
    help="Provide a complete address to fetch geographical coordinates."
)

# ---------------------------
# Geocoding Function with Caching
# ---------------------------

# Check Streamlit version for appropriate caching decorator
if hasattr(st, 'cache_data'):
    cache_decorator = st.cache_data
else:
    cache_decorator = st.cache

@cache_decorator(ttl=3600)
def get_location(address):
    try:
        return geolocator.geocode(address)
    except GeocoderServiceError as e:
        logging.error(f"Geocoding service error: {e}")
        return None

latitude, longitude = None, None
if address:
    location = get_location(address)
    if location:
        latitude = location.latitude
        longitude = location.longitude
        st.success(f"✅ Location found: Latitude {latitude}, Longitude {longitude}")
    else:
        st.error("❌ Address not found. Please enter a valid address.")

# ---------------------------
# Additional Property Features
# ---------------------------
state_building = st.selectbox(
    "🏢 Select the state of the building:",
    [
        "GOOD",
        "JUST_RENOVATED",
        "MISSING",
        "TO_BE_DONE_UP",
        "TO_RENOVATE",
        "TO_RESTORE"
    ],
    help="Current condition or state of the building."
)

province = st.selectbox(
    "📍 Select the province:",
    [
        "Brussels",
        "East Flanders",
        "Flemish Brabant",
        "Hainaut",
        "Limburg",
        "Liège",
        "Luxembourg",
        "Namur",
        "Walloon Brabant",
        "West Flanders"
    ],
    help="Province where the property is located."
)

heating_type = st.selectbox(
    "🔥 Select the heating type:",
    [
        "ELECTRIC",
        "FUELOIL",
        "GAS",
        "MISSING",
        "PELT",
        "SOLAR",
        "WOOD"
    ],
    help="Type of heating system used in the property."
)

# ---------------------------
# Prediction Button and Logic
# ---------------------------
predict_enabled = latitude is not None and longitude is not None

if st.button("🔮 Predict Price"):
    if predict_enabled:
        # Prepare the input data as a JSON object
        data = {
            "total_area_sqm": total_area_sqm,
            "construction_year": construction_year,
            "nbr_bedrooms": nbr_bedrooms,
            "longitude": longitude,
            "latitude": latitude,
            "fl_floodzone": fl_floodzone,
            "terrace_sqm": terrace_sqm,
            "fl_terrace": fl_terrace,
            "state_building": state_building,
            "province": province,
            "heating_type": heating_type
        }

        try:
            # ---------------------------
            # API Configuration
            # ---------------------------
            # It's recommended to store sensitive information like API URLs and keys in Streamlit secrets
            # For example, in the .streamlit/secrets.toml file:
            # API_URL = "https://your-api-endpoint.com"
            # API_KEY = "your_api_key_here"  # If authentication is required

            API_URL = st.secrets["API_URL"]  # e.g., "https://api.example.com"
            # Uncomment and use the following line if your API requires an API key
            # API_KEY = st.secrets["API_KEY"]

            headers = {
                "Content-Type": "application/json"
                # "Authorization": f"Bearer {API_KEY}"  # Uncomment if using API key
            }

            # ---------------------------
            # Send POST Request to FastAPI
            # ---------------------------
            with st.spinner("🔄 Predicting price..."):
                response = requests.post(f"{API_URL}/predict/", json=data, headers=headers)

            # ---------------------------
            # Handle API Response
            # ---------------------------
            if response.status_code == 200:
                prediction = response.json()
                predicted_price = prediction.get('predicted_price')
                if predicted_price is not None:
                    st.success(f"The predicted price is: **€{predicted_price:,.2f}**")
                else:
                    st.error("❌ Prediction key not found in the API response.")
                    logging.error(f"Unexpected API response structure: {prediction}")
            else:
                st.error(f"❌ Failed to get prediction from the model. Status code: {response.status_code}")
                logging.error(f"API response error: {response.status_code} - {response.text}")

        except Exception as e:
            logging.error(f"Prediction request failed: {e}")
            st.error(f"❌ Prediction request failed: {e}")
    else:
        st.warning("⚠️ Please ensure the address is valid before predicting.")

# ---------------------------
# Footer
# ---------------------------
st.markdown("""
---
*Developed with ❤️ using Streamlit and FastAPI.*
""")
# Out:
# 2024-11-13 14:40:57.871 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.143
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Becode-son\Desktop\API-ML\env\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-13 14:40:58.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.151 Session state does not function when running a script without `streamlit run`
# 2024-11-13 14:40:58.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.183 No runtime found, using MemoryCacheStorageManager
# 2024-11-13 14:40:58.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:40:58.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
